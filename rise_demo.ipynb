# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()
plt.scatter(*np.random.randn(2, 1000))
fig, ax = plt.subplots()
plt.scatter(*np.random.randn(2, 1000))
fig, ax = plt.subplots()
plt.scatter(*np.random.randn(2, 1000))
fig, ax = plt.subplots()
plt.scatter(*np.random.randn(2, 1000))
